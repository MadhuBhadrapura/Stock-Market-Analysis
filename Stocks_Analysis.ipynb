# %% [markdown]
# ## 1. Reading the Data from Yahoo finance website directly

# %%
import datetime as dt
from dateutil.relativedelta import relativedelta as rd

# %%
start = dt.datetime.today() - rd(years = 1 )
end = dt.datetime.today() - rd(day=1, days=1)

# %%
import pandas as pd
import pandas_datareader.data as  pd_data

# %%
apple = pd_data.DataReader('AAPL', 'yahoo', start, end)
google = pd_data.DataReader('GOOGL', 'yahoo', start, end)
microsoft = pd_data.DataReader('MSFT', 'yahoo', start, end)
amazon = pd_data.DataReader('AMZN', 'yahoo', start, end)

# %% [markdown]
# ## 2. Performing cleaning

# %%
#1
apple.isnull()
apple.dropna(inplace = True)
from numpy import NaN
apple.replace({NaN:0.00})
#2
google.isnull()
google.dropna(inplace = True)
from numpy import NaN
google.replace({NaN:0.00})
#3
microsoft.isnull()
microsoft.dropna(inplace = True)
from numpy import NaN
microsoft.replace({NaN:0.00})
#4
amazon.isnull()
amazon.dropna(inplace = True)
from numpy import NaN
amazon.replace({NaN:0.00})
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2021-09-13  174.897995  171.899994  174.139999  172.858505  51380000.0
# 2021-09-14  174.340500  171.885498  173.777496  172.500000  38738000.0
# 2021-09-15  174.270996  170.100494  172.126007  173.789505  59150000.0
# 2021-09-16  174.627502  172.307007  172.998001  174.412003  51672000.0
# 2021-09-17  174.870499  172.606506  174.420502  173.126007  92332000.0
# ...                ...         ...         ...         ...         ...
# 2022-08-25  137.419998  134.279999  135.259995  137.279999  37496300.0
# 2022-08-26  137.830002  130.500000  136.550003  130.750000  53322700.0
# 2022-08-29  131.949997  128.770004  129.899994  129.789993  48101600.0
# 2022-08-30  132.070007  126.849998  131.250000  128.729996  49203000.0
# 2022-08-31  130.589996  126.739998  129.449997  126.769997  53648700.0
#
#              Adj Close
# Date
# 2021-09-13  172.858505
# 2021-09-14  172.500000
# 2021-09-15  173.789505
# ...

# %% [markdown]
# ### % of missing.

# %%
import numpy as np

#1
for col in apple.columns:
    pct_missing = np.mean(apple[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))

#2
for col in google.columns:
    pct_missing = np.mean(google[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
    
#3
# % of missing.
for col in microsoft.columns:
    pct_missing = np.mean(microsoft[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
    
#4
# % of missing.
for col in amazon.columns:
    pct_missing = np.mean(amazon[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# High - 0%
# Low - 0%
# Open - 0%
# Close - 0%
# Volume - 0%
# Adj Close - 0%
# High - 0%
# Low - 0%
# Open - 0%
# Close - 0%
# Volume - 0%
# Adj Close - 0%
# High - 0%
# Low - 0%
# Open - 0%
# Close - 0%
# Volume - 0%
# Adj Close - 0%
# High - 0%
# Low - 0%
# Open - 0%
# Close - 0%
# Volume - 0%
# Adj Close - 0%

# %% [markdown]
# ## 3. Visualizing the change in a stock’s volume being traded, over time

# %%
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

apple['Volume'].plot(label = 'Apple', figsize = (15,7))
google['Volume'].plot(label = 'Google')
microsoft['Volume'].plot(label = 'Microsoft')
amazon['Volume'].plot(label = 'Amazon')
plt.title('Stock volumes of Apple, Google, Microsoft and Amazon')
plt.legend()

# %%
# other way

fig = plt.figure(figsize=(15,7))
ax1 = fig.add_subplot(321)
ax2 = fig.add_subplot(322)
ax3 = fig.add_subplot(323)
ax4 = fig.add_subplot(324)
ax1.plot(apple['Volume'])
ax1.set_title("Stock volume ofApple")
ax2.plot(google['Volume'])
ax2.set_title("Stock volume Google")
ax3.plot(microsoft['Volume'])
ax3.set_title("Stock volume Microsoft")
ax4.plot(amazon['Volume'])
ax4.set_title("Stock volume Amazon")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Moving average of various stocks

# %%
# MA for apple stocks
apple['MA50'] = apple['Open'].rolling(50).mean()     # 50 day moving average
apple['MA200'] = apple['Open'].rolling(200).mean()   # 200 day moving average
apple['Open'].plot(figsize = (15,7))
apple['MA50'].plot()
apple['MA200'].plot()
plt.title('Moving average for Apple stocks')
plt.legend()

# %%
# MA for google stocks
google['MA50'] = google['Open'].rolling(50).mean()     # 50 day moving average
google['MA200'] = google['Open'].rolling(200).mean()   # 200 day moving average
google['Open'].plot(figsize = (15,7))
google['MA50'].plot()
google['MA200'].plot()
plt.title('Moving average for Google stocks')
plt.legend()

# %%
# MA for microsoft stocks
microsoft['MA50'] = microsoft['Open'].rolling(50).mean()     # 50 day moving average
microsoft['MA200'] = microsoft['Open'].rolling(200).mean()   # 200 day moving average
microsoft['Open'].plot(figsize = (15,7))
microsoft['MA50'].plot()
microsoft['MA200'].plot()
plt.title('Moving average for Microsoft stocks')
plt.legend()

# %%
# MA for amazon stocks
amazon['MA50'] = amazon['Open'].rolling(50).mean()     # 50 day moving average
amazon['MA200'] = amazon['Open'].rolling(200).mean()   # 200 day moving average
amazon['Open'].plot(figsize = (15,7))
amazon['MA50'].plot()
amazon['MA200'].plot()
plt.title('Moving average for Amazon stocks')
plt.legend()

# %%
# Moving Average of 50 days

fig = plt.figure(figsize=(15,7))
ax1 = fig.add_subplot(321)
ax2 = fig.add_subplot(322)
ax3 = fig.add_subplot(323)
ax4 = fig.add_subplot(324)
ax1.plot(apple['MA50'])
ax1.set_title("Apple")
ax2.plot(google['MA50'])
ax2.set_title("Google")
ax3.plot(microsoft['MA50'])
ax3.set_title("Microsoft")
ax4.plot(amazon['MA50'])
ax4.set_title("Amazon")

plt.tight_layout()
plt.show()

# %%
# Moving Average of 200 days

fig = plt.figure(figsize=(15,7))
ax1 = fig.add_subplot(321)
ax2 = fig.add_subplot(322)
ax3 = fig.add_subplot(323)
ax4 = fig.add_subplot(324)
ax1.plot(apple['MA200'])
ax1.set_title("Apple")
ax2.plot(google['MA200'])
ax2.set_title("Google")
ax3.plot(microsoft['MA200'])
ax3.set_title("Microsoft")
ax4.plot(amazon['MA200'])
ax4.set_title("Amazon")

plt.tight_layout()

# %% [markdown]
# ## 5. Daily return average of a stock

# %%
apple['Daily Return'] = apple['Adj Close'].pct_change()*100
google['Daily Return'] = google['Adj Close'].pct_change()*100
microsoft['Daily Return'] = microsoft['Adj Close'].pct_change()*100
amazon['Daily Return'] = amazon['Adj Close'].pct_change()*100

# %%
apple['Daily Return'].hist(bins = 100, label = 'Apple', alpha = 0.5, figsize = (15,7))
google['Daily Return'].hist(bins = 100, label = 'Google', alpha = 0.5)
microsoft['Daily Return'].hist(bins = 100, label = 'Microsoft', alpha = 0.5)
amazon['Daily Return'].hist(bins = 100, label = 'Amazon', alpha = 0.5)
plt.legend()

# %% [markdown]
# ## 6. Add a new column ‘Trend’ whose values are based on the 'Daily Return'

# %%
def trend(x):
  if x > -0.5 and x <= 0.5:
    return 'Slight or No change'
  elif x > 0.5 and x <= 1:
    return 'Slight Positive'
  elif x > -1 and x <= -0.5:
    return 'Slight Negative'
  elif x > 1 and x <= 3:
    return 'Positive'
  elif x > -3 and x <= -1:
    return 'Negative'
  elif x > 3 and x <= 7:
    return 'Among top gainers'
  elif x > -7 and x <= -3:
    return 'Among top losers'
  elif x > 7:
    return 'Bull run'
  elif x <= -7:
    return 'Bear drop'

apple['Trend']= apple['Daily Return'].apply(lambda x:trend(x))
google['Trend']= google['Daily Return'].apply(lambda x:trend(x))
microsoft['Trend']= microsoft['Daily Return'].apply(lambda x:trend(x))
amazon['Trend']= amazon['Daily Return'].apply(lambda x:trend(x))

# %% [markdown]
# ## 7. Visualizing trend frequency through a Pie Chart

# %%
colors = ["turquoise", "hotpink", "fuchsia",'aquamarine', "teal", "plum", "lightcoral", "purple"]

# %%
av = apple.Trend.value_counts()
av.values
plt.figure(figsize = (20, 5))
plt.pie(av.values, 
        labels= av.index, autopct= '%2.2f %%',
       textprops= {'color' : 'fuchsia', 'size' : 9, 'weight' : 'bold'},
       wedgeprops= {'edgecolor' : 'gray'},
        colors =colors, shadow = True
       )
plt.title('Trend of Apple stocks', color = 'brown', weight = 'bold', size = 20, pad = 5, loc = 'left')
plt.show()

# %%
gv = google.Trend.value_counts()
gv.values
plt.figure(figsize = (20, 5))
plt.pie(gv.values, 
        labels= gv.index, autopct= '%2.2f %%',
       textprops= {'color' : 'fuchsia', 'size' : 9, 'weight' : 'bold'},
       wedgeprops= {'edgecolor' : 'gray'},
        colors =colors, shadow = True
       )
plt.title('Trend of Google stocks', color = 'brown', weight = 'bold', size = 20, pad = 5, loc = 'left')
plt.show()

# %%
mv = microsoft.Trend.value_counts()
mv.values
plt.figure(figsize = (20, 5))
plt.pie(mv.values, 
        labels= mv.index, autopct= '%2.2f %%',
       textprops= {'color' : 'fuchsia', 'size' : 9, 'weight' : 'bold'},
       wedgeprops= {'edgecolor' : 'gray'},
        colors =colors, shadow = True
       )
plt.title('Trend of Microsoft stocks', color = 'brown', weight = 'bold', size = 20, pad = 5, loc = 'left')
plt.show()

# %%
azv = google.Trend.value_counts()
azv.values
plt.figure(figsize = (20, 5))
plt.pie(azv.values, 
        labels= azv.index, autopct= '%2.2f %%',
       textprops= {'color' : 'fuchsia', 'size' : 9, 'weight' : 'bold'},
       wedgeprops= {'edgecolor' : 'gray'},
        colors =colors, shadow = True
       )
plt.title('Trend of Amazon stocks', color = 'brown', weight = 'bold', size = 20, pad = 5, loc = 'left')
plt.show()

# %% [markdown]
# ## 8. Correlation between the daily returns of different stocks

# %%
data = pd.concat([apple['Daily Return'],google['Daily Return'],microsoft['Daily Return'],amazon['Daily Return']],axis = 1)
data.columns = ['APPLE Daily Return','GOOGLE Daily Return','MICROSOFT Daily Return', 'AMAZON Daily Return']
scatter_matrix(data, figsize = (10,10), hist_kwds= {'bins':250})
# Out:
# array([[<AxesSubplot:xlabel='APPLE Daily Return', ylabel='APPLE Daily Return'>,
#         <AxesSubplot:xlabel='GOOGLE Daily Return', ylabel='APPLE Daily Return'>,
#         <AxesSubplot:xlabel='MICROSOFT Daily Return', ylabel='APPLE Daily Return'>,
#         <AxesSubplot:xlabel='AMAZON Daily Return', ylabel='APPLE Daily Return'>],
#        [<AxesSubplot:xlabel='APPLE Daily Return', ylabel='GOOGLE Daily Return'>,
#         <AxesSubplot:xlabel='GOOGLE Daily Return', ylabel='GOOGLE Daily Return'>,
#         <AxesSubplot:xlabel='MICROSOFT Daily Return', ylabel='GOOGLE Daily Return'>,
#         <AxesSubplot:xlabel='AMAZON Daily Return', ylabel='GOOGLE Daily Return'>],
#        [<AxesSubplot:xlabel='APPLE Daily Return', ylabel='MICROSOFT Daily Return'>,
#         <AxesSubplot:xlabel='GOOGLE Daily Return', ylabel='MICROSOFT Daily Return'>,
#         <AxesSubplot:xlabel='MICROSOFT Daily Return', ylabel='MICROSOFT Daily Return'>,
# ...

# %% [markdown]
# #### All the four stocks are showing positive correlation with each other
